# %%
import pandas as pd

# %%
assert(2+3) == (2*3)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_944/4093040075.py in <module>
# ----> 1 assert(2+3) == (2*3)
#
# AssertionError:
